# %%
import pandas as pd
import numpy as np

traffic = pd.DataFrame({
    'source_ip': ['192.168.1.10', '192.168.1.10', '10.0.0.15', '203.0.113.50', '192.168.1.10',
                   '10.0.0.15', '203.0.113.50', '198.51.100.7', '10.0.0.15', '198.51.100.7',
                   '192.168.1.10', '203.0.113.50'],
    'dest_port': [22, 22, 443, 22, 80, 3389, 22, 443, 22, 21, 22, 22],
    'packet_size': [1200, 1350, 500, np.nan, 300, 700, 9500, 450, 1100, np.nan, 1400, 8800],
    'protocol': ['TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP', 'TCP'],
    'is_malicious': [1, 1, 0, 1, 0, 0, 1, 0, 1, 0, 1, 1]
})
# print(traffic.head())
# traffic.info()
# traffic['packet_size'].describe()  #min value 2530 ha but ,max value 9500 ha 
traffic[['source_ip','dest_port']]
# print(traffic[traffic['dest_port']==22])
# print(traffic[(traffic['is_malicious']==1)&(traffic['packet_size']>1000)])
# print(traffic.isnull().sum())
# traffic_clean = traffic.dropna()
# print(traffic_clean)
# print(traffic_clean['source_ip'].value_counts())
# print(traffic_clean.groupby("dest_port")['is_malicious'].sum())
# print(traffic_clean.groupby('source_ip')['packet_size'].mean())
# Out:
#        source_ip  dest_port
# 0   192.168.1.10         22
# 1   192.168.1.10         22
# 2      10.0.0.15        443
# 3   203.0.113.50         22
# 4   192.168.1.10         80
# 5      10.0.0.15       3389
# 6   203.0.113.50         22
# 7   198.51.100.7        443
# 8      10.0.0.15         22
# 9   198.51.100.7         21
# 10  192.168.1.10         22
# 11  203.0.113.50         22
